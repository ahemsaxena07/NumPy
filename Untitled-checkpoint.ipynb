# %%
import numpy as np

# %%
data = np.array([[1,4,2],[0.3, -3, 0.6]])

# %%
data
# Out:
# array([[ 1. ,  4. ,  2. ],
#        [ 0.3, -3. ,  0.6]])

# %%
import numpy as np

# %%
data = np.array([[1,4,2],[0.3, -3, 0.6]])

# %%
data + data
# Out:
# array([[ 2. ,  8. ,  4. ],
#        [ 0.6, -6. ,  1.2]])

# %%
data.shape
# Out:
# (2, 3)

# %%
data.dtype
# Out:
# dtype('float64')
